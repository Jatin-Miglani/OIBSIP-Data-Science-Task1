# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv("/content/Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.info
# Out:
# <bound method DataFrame.info of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#from sklearn.preprocessing import StandardScaler
#scaler= StandardScaler()
#x=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']

# %%
#df[x] = scaler.fit_transform(df[x])
#df[x]

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
y=df[['Species']]
y.head()
# Out:
#        Species
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
#label Encoding
df['Species_new']=df['Species'].map({"Iris-setosa":3,"Iris-versicolor":2,"Iris-virginica":1})
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    Species_new
# 0            3
# 1            3
# 2            3
# 3            3
# 4            3

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  Species_new
# 0       Iris-setosa            3
# 1       Iris-setosa            3
# 2       Iris-setosa            3
# ...

# %%
df=df.drop(columns="Species")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#      Species_new
# 0              3
# 1              3
# 2              3
# 3              3
# 4              3
# ..           ...
# 145            1
# ...

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000
#
#        Species_new
# count   150.000000
# mean      2.000000
# std       0.819232
# min       1.000000
# 25%       1.000000
# 50%       2.000000
# 75%       3.000000
# max       3.000000

# %%
sns.countplot(x='Species_new',data=df)
plt.show()

# %%
sns.pairplot(df,hue='Species_new',markers='x')
plt.show()

# %%
df.boxplot(figsize=(8,6))
# Out:
# <Axes: >

# %%
plt.figure(figsize = (7,4))
sns.heatmap(df.corr(), annot = True, cmap="Reds")
# Out:
# <Axes: >

# %%
x=df.drop("Species_new",axis=1)
y=df["Species_new"]
x=x.drop("Id",axis=1)

# %%
x
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0      3
# 1      3
# 2      3
# 3      3
# 4      3
#       ..
# 145    1
# 146    1
# 147    1
# 148    1
# 149    1
# Name: Species_new, Length: 150, dtype: int64

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.8,random_state=3267)

# %%
x_test
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 117            7.7           3.8            6.7           2.2
# 102            7.1           3.0            5.9           2.1
# 87             6.3           2.3            4.4           1.3
# 31             5.4           3.4            1.5           0.4
# 61             5.9           3.0            4.2           1.5
# ..             ...           ...            ...           ...
# 25             5.0           3.0            1.6           0.2
# 73             6.1           2.8            4.7           1.2
# 19             5.1           3.8            1.5           0.3
# 47             4.6           3.2            1.4           0.2
# 130            7.4           2.8            6.1           1.9
#
# [120 rows x 4 columns]

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(x_train,y_train)
ypred=lr.predict(x_test)

# %%
ypred
# Out:
# array([1, 1, 2, 3, 2, 1, 3, 3, 1, 2, 1, 2, 1, 3, 3, 3, 3, 2, 3, 2, 1, 3,
#        3, 2, 3, 1, 3, 2, 2, 3, 1, 2, 3, 3, 2, 3, 2, 3, 1, 2, 1, 3, 2, 2,
#        1, 3, 1, 2, 1, 1, 1, 3, 1, 2, 1, 1, 2, 1, 1, 1, 1, 3, 1, 1, 1, 3,
#        3, 2, 2, 1, 2, 3, 1, 1, 2, 2, 1, 2, 3, 3, 2, 2, 3, 3, 1, 3, 2, 1,
#        3, 3, 2, 3, 1, 2, 3, 1, 3, 2, 2, 3, 1, 2, 3, 3, 3, 3, 2, 3, 3, 2,
#        3, 1, 3, 2, 2, 3, 2, 3, 3, 1])

# %%
y_test
# Out:
# 117    1
# 102    1
# 87     2
# 31     3
# 61     2
#       ..
# 25     3
# 73     2
# 19     3
# 47     3
# 130    1
# Name: Species_new, Length: 120, dtype: int64

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,ypred)
r2
# Out:
# 0.9749973955620377

# %%
accuracy =[]
for i in range(10000):
  x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.8,random_state=i)
  model1= LogisticRegression()
  model1.fit(x_train,y_train)
  ypred=lr.predict(x_test)
  r2_1=r2_score(y_test,ypred)
  accuracy.append(r2_1)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
np.max(accuracy)
# Out:
# 1.0

# %%
np.argmax(accuracy)
# Out:
# 634

# %%
import joblib
joblib.dump(lr,'Iris.pkl')
# Out:
# ['Iris.pkl']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.8,random_state=3267)
lr = LogisticRegression()
lr.fit(x_train,y_train)
ypred=lr.predict(x_test)
r2=r2_score(y_test,ypred)
r2
# Out:
# 0.9749973955620377

# %%
def get_predicted_class(x1,x2,x3,x4):

    predicted_class=lr.predict([[x1,x2,x3,x4]])

    j=pd.DataFrame(predicted_class)
    if(j[0][0]==3):
      return("Iris Setosa")

    if(j[0][0]==2):
      return("Iris Versicolor")

    if(j[0][0]==1):
      return("Iris Virginica")


sepal_length=int(input('Enter the value of SepalLengthCm : '))
sepal_width=int(input('Enter the value of SepalWidthCm : '))
petal_length=int(input('Enter the value of PetalLengthCm : '))
petal_width=int(input('Enter the value of PetalWidthCm : '))


get_predicted_class(sepal_length,sepal_width,petal_length,petal_width)
# Out:
# Enter the value of SepalLengthCm : 5
# Enter the value of SepalWidthCm : 3
# Enter the value of PetalLengthCm : 1
# Enter the value of PetalWidthCm : 1
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# 'Iris Setosa'
